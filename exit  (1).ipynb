# %%
from tkinter import ttk
import tkinter as tk
from tkinter import *
from tkinter import ttk
from tkinter import messagebox

root = Tk()
root.geometry("1920x1080")
frm = ttk.Frame(root, padding=10)
custom_font =("arial", 32)
frm.grid(column=0, row=0) 

frm.columnconfigure(0, weight=1)
frm.rowconfigure(0, weight=1)

ttk.Label(frm, text="--> Self-identifying the mental health status and get guidance for support. <--", font=custom_font).grid(column=0, row=1)
ttk.Label(frm, text="Select any disorder to assess whether you may be suffering from a following", font=custom_font).grid(column=0, row=2)
ttk.Label(frm, text="issue And get suggestions/response as per your suffering status", font=custom_font).grid(column=0, row=3)
ttk.Label(frm, text="-  Note :- This project is for adults. ", font=custom_font).grid(column=0, row=4)
style = ttk.Style()
style.configure("Green.TButton", foreground="Black", background="green")

next_button = ttk.Button(root, text="Next", command=root.destroy, style="Green.TButton")
next_button.grid(column=0, row=6)

root.mainloop()

class DisorderAssessment:
    def __init__(self, root):
        
        root.geometry("1920x1080")
        frm = ttk.Frame(root, padding=10)

        self.root = root
        self.root.title("Disorder Self-Assessment")

        self.disorder_var = tk.StringVar()
        self.disorder_var.set("None")  

        self.questions = {
            "DEPRESSION": [
                "1) Do you face difficulty focusing on everyday tasks?",
                "2) Finding no joy in life, or feeling like you never will again?",
                "3) Do you feel being lethargic or having no energy?",
                "4) Are you eating too much,or too little?",
                "5) Do you feel full of nervous energy, or moving much less than usual?",
                "6) Does oversleeping, or struggling to get to sleep?",
                "7) Have you been harsh on yourself or overly self-critical?",
                "8) Do you feel low or 'under a cloud'?",
                "9) Do you consider harming yourself, or commiting suicide?",
                "10) Do you get headaches, cramps, aches, or pains that won't go away?",
                "11) Do you feel loss of interest or pleasure in things you previously found enjoyable?",
                "12) Do you Feel angry, irritable, or frustrated, even over small matters?",
                "13) Does depression slowed thinking, speaking, or body movements?"
            ],
            "ANXIETY": [
                "1) Have you been unable to stay in one place - like sitting down - for any length of time?",
                "2) Have you been very concerned about several things at one time?",
                "3) Have you been agitated , tense , or skittish?",
                "4) Do you feel unable to feel clam or relaxed?",
                "5) Have you struggled to control feelings of anxiety , agitation , or fear?",
                "6) Have you felt bad-tempered , irritable , or moody?",
                "7) Have you been afraid or panicky about bad things that might happen to myself or others?"
            ],
            "PERSONALITY DISORDER": [
                "1) Are you often suspicious of others' motives?",
                "2) Do you have a fear of abandonment or being alone?",
                "3) Do you have a history of impulsive behavior, such as reckless driving or substance abuse?",
                "4) Do you often experience intense mood swings and unstable self-image?",
                "5)re you frequently preoccupied with fantasies of success, power, or attractiveness?",
                "6) Do you tend to avoid social interactions and prefer solitude?"
            ],
            "EATING DISORDER": [
                "1) Do you try avoid eating in front of others?",
                "2) Have you sometimes hide food in strange places?",
                "3) Do you eat until I am uncomfortably full?",
                "4) Do you force myself to vomit after eating large meals?",
                "5) Do you often think about food , my weight , weight loss , exercise , etc?",
                "6) Do you take diet pills , laxatives , or diuretics to help control my weight?",
                "7) Do you obsessively count calories?",
                "8) Do you prepare nice meals but refuse to eat them?",
                "9) Do you wear loose fitting clothes to hide my body?",
                "10) Do you often make comments about being 'fat'?",
                "11) Do you don't think exterme thinness is a problem?",
                "12) Do you have an intense fear of gaining weight?"
            ],
            "INTERNET ADDICTION DISORDER": [
                "1) Do you find yourself 'zoning out' when online or becoming irritable when someone interrupts you while you are online?",
                "2) Do you find that you are unable to drag yourself away from being online,or promising yourself 'just another 5 minutes'?",
                "3) Have you lied about how much time you spend online?",
                "4) Do you use time on the internet to avoid thoughts about problems or issues in your life?",
                "5) After going offline,do you find yourself thinking about when you'll next be able to go online?",
                "6) Do people close to you comment negatively about the amount of time you spend on the internet or social media?",
                "7) Have you become irritable or annoyed when someone comments on how much time you spend online?",
                "8) Do you feel like being without the internet would be a serious issue for you?",
                "9) Do you feel irritable or agitated when offline,only to find that those feelings subside when you go online?",
                "10) Do you make new friends with other online users?",
                "11) Do you submit work or school assignments late because of the time you spend online?",
                "12) Does being online interfere with responsibilities in your life like work,projects,or chores?"
            ],
            "SEX ADDICTION": [
                "1) Have you attempted to suppress or stop specific sexual behaviors or activity?",
                "2) Does your sexual behavior or thoughts ever make you feel guilty or regretful?",
                "3) Does thinking about real-life interactions, do you pursue some sexual behaviors or forms of sexual release anonymously or with complete strangers?",
                "4) Do you sometimes feel overwhelmed by your sexual oppetites?",
                "5) Do you sexual desires dominate your everyday thinking?",
                "6) Do you ever have obsessive thoughts of a sexual nature that you struggle to get out of your mind?",
                "7) Have you broken local laws relating to sexual behaviors where you live?",
                "8) Have you suffered past sexual abuse?",
                "9) Have you previously sought help for negative or damaging sexual behaviors by, for example, going to a therapist?",
                "10) Have you tried and failed to stop specific sexual behaviors?",
                "11) Would you describe your sexual behaviors as abnormal or unusual?",
                "12) Have you neglected parts of your life - at your job, at home, time with friends and family - in pursuit of your sexual desires?",
                "13) Would you regard sex, or the pursuit of sex, as the most important thing that drives you?"
            ],
            "FEMALE AGRESSION": [
                "1) Do you some time or other you have threatened someone close to you?",
                "2) Does your temper can settle down almost as quickly as you lose it?",
                "3) If you get pushed too far you'll hit someone?",
                "4) Do you find that it's others, not me , that tend to get all the luck?",
                "5) Do you lose my temper quite easily?",
                "6) Have been provoked into physical violence with one or more people?",
                "7) Do you get angry sometimes and lose your temper for no reason?",
                "8) Have you been told you are combative in arguments?",
                "9) Do you sometimes feel like life has disadvantaged me in many ways?",
                "10) Do you frequently find myself in loud disagreement with others?",
                "11) Do you sometimes feel resentful about the things and people around me?",
                "12) Do you find it very hard to step away from a disagreement or debate?"
            ],
            "SLEEP DISORDER": [
                "1) Do you face difficulty falling or staying asleep?",
                "2) Do you feel fatigued during the day?",
                "3) Does your performance at work, school or other duties has been negatively impacted?",
                "4) Do you wake up feeling tired or exhausted?",
                "5) Do you have to get out of bed to use the restroom?",
                "6) Do you experience upleasant urges to move while falling asleep?",
                "7) Do you have trouble focusing or concentrating during my waking hours?",
                "8) Do you feel irritable or anxious?",
                "9) Do you face trouble maintaining a consistent sleep schedule?",
                "10) Do you feel strong urge to take a nap during the day?"
            ],
            "VIDEO GAME ADDICTION": [
                "1) Does your gaming interfere with responsibilities in your life like tasks, work, project, or chores?",
                "2) Has your school work or paid employment suffered because of the amount of time you spend gaming?",
                "3) Have you increased the amount of money and time you spend on video games in order to match the satisfaction you get from other areas of your life?",
                "4) Are there problems in your life for which video games provide a welcome sense of escape?",
                "5) Have you failed to submit work or homework on time because of the time you spent gaming?",
                "6) Have you ever borrowed or stolen money to buy a video game, or stolen a video game or games console?",
                "7) If you try to cut down, or even quit, gaming do you become agitated or bad-tempered?",
                "8) Have you ever found yourself in financial difficulty because of the amount you've spent on gaming?",
                "9) Do you find you spend much more time than you used to playing video games?",
                "10) Have you tried but failed to cut down the length of your gaming sessions?",
                "11) Have you found yourself lying to others about how much time you are spending gaming?"
            ],
            "TOXIC WORKPLACE" : [
                "1) Are you always worried that i might be let go at a moment's notice?",
                "2) Does your work enviorment makes it difficult to concentrate or focus on a task?",
                "3) Does stress-related issues cause me to take sick days from work?",
                "4) Is there a lot of micromanagement and needless bureaucracy at your company?",
                "5) Does your workplace performance manages colleagues who aren't doing their fair share?",
                "6) Do you get emotional support from one or more colleagues?",
                "7) When your friends or family ask about your job you tend to respond quite negatively?",
                "8) In your busy times you can rely on your manager to help out?",
                "9) Is your manager realistic about what you are able to achieve during working hours?",
                "10) Do you feel like you can trust your colleagues to support you personally and professionally?",
                "11) Do you find yourself thinking about or looking for another job?",
                "12) Does your work-realated stress has negatively impacted relationships with people close to you?",
                "13) Have you been afraid to take paid time off because you're worried that doing so will put your job at risk?"
            ],
            "Male Aggression": [
                "1) Have you been told you're combative in arguments or debates?",
                "2) If you're pushed too far are you capable of hitting someone?",
                "3) Does your temper can settle down almost as quickly as you lose it?",
                "4) Have you been provoked into physical violence with one or more people?",
                "5) Do you sometimes feel like life has disadvantaged you in many ways?",
                "6) Do you sometimes get angry and lose your temper for no reason?",
                "7) Do you sometime feel sudden resentment about the things and people around me?",
                "8) Do you find that it's others , not you , that tend to get all the luck?",
                "9) Do you find it very hard to step away from a disagreement?",
                "10) Do you frequently find yourself in loud disagreement with others?",
                "11) Have you been got a short fuse and can lose your temper quite easily?",
                "12) Have you some time or other you have threatened someone close to you?"
            ],
            "SCHIZOPHRENIA" : [
                "1) Are other people unable to see or hear things that you can?",
                "2) Do sometimes you are not able to speak at all?",
                "3) Do have a diagnosis for something which you have been told may alter your behavior?",
                "4) Does organizing and getting on with your work can be very difficult?",
                "5) Do you believe you have powers that regular people do not have?",
                "6) When you speak, the words come out wrong or not how you intend, do people tell you that you're not making sense?",
                "7) Can you hear conversations between people that others cannot hear?",
                "8) Can you hear other people talking or whispering about you so quitely that others don't notice?",
                "9) Do you sometimes feel that others may intend to harm you or are planning to harm you?",
                "10) Do you sometimes completely lack emotions, like you're robot?",
                "11) Do you sometimes believe that another person or thing can take charge of mind or body?",
                "12) Do you sometimes feel unable to tell whether something you're seeing is real or whether you are imagining it?",
                "13) Can you tell what is going to happen before it happens?",
                "14) Do you sometimes believe that you're able to read minds, or other people can read yours?"
            ],
            "EMPATHY DEFICIT DISORDER TEST": [
                "1) Do you find it hard to feel sympathetic  for someone who is experiencing unkind or unfair behavior?",
                "2) Do you attempt to change the topic of conversation when a family member or friend wants to talk about what's troubling them?",
                "3) Does other people's emotional states and moods aren't that important to you?",
                "4) When someone is ill because of their own unhealthy behaviors, are you sorry for them?",
                "5) Do you get enthusiastic when another person is feeling enthusiastic?",
                "6) Do you feel much when a family member of friend is happy about something?",
                "7) Do you get annoyed when someone you're around gets tearful?",
                "8)Can you know if another person is unhappy even if they haven't told you so?",
                "9) Whenever you see a person who is distressed, do you feel compelled to assist them?",
                "10) When bad things to happen to other people, does it bother you very much?",
                "11) Do you feel compassionate and sympathetic towards people who aren't as lucky as you are?",
                "12) Can you see other people being tearful when they're happy?",
                "13) Does cheering other people up makes me feel good?"
            ],
            "REPETITIVE THOUGHTS AND BEHAVIORS": [
                "1) Do your thoughts and behaviors cause problems with school, your job, or your life in general (for example, with your family or friends)?",
                "2) Do you spend each day repeating thoughts or behaviors?",
                "3) Do you get upset when these thoughts or behaviors make you?",
                "4) Does your thoughts and behaviors stops you from doing things you want to do, like visiting people or places?",
                "5) Are you able to control these thoughts or behaviors?"
            ],
            "PSYCHOSIS": [
                "1) Do you sometimes see things that others tell you they cannot see?",
                "2) Do you sometimes feel the presence of someone around you despite being alone?",
                "3) Do you sometimes feel that someone or something else controls your thoughts?",
                "4) Do you frequently feel like other people are plotting against you?",
                "5) Do you feel that your body is different or behaves in a different way to how it used to?",
                "6) Do you frequently hear strange sounds like crashing or ringing?",
                "7) Have you lost interest in things you used to like?",
                "8) Do you find that you experience smells or tastes that others cannot?",
                "9) Have you seen someone's face change in front of you , or your own face has changed in the mirror?",
                "10) Does meeting new people makes you very nervous or stressed?",
                "11) Do you sometimes hear voices that others cannot?",
                "12) Do you always feel that you're not sure if something has actually happened , or whether you imagined it?",
                "13) Do you sometimes spot hidden messages in adverts on television , in shop displays , or in how things are arranged?"
            ],
            "BIPOLAR DISORDER": [
                "1) You couldn't shut your mind off or stop thoughts rushing through your mind?",
                "2) Have you experienced feelings of anguish or desperation?",
                "3) Are you much more socially active than normal , and at all hours?",
                "4) Does your behavior was unsafe or risky in a way that wasn't normal for you?",
                "5) Have you felt exhausted or unusually fatigued?",
                "6) Do you get angry , aggressive or violent towards others?",
                "7) Do you talk a lot more or a lot faster than normal?",
                "8) Do you take risks with your finances which caused problems for yourself or others?",
                "9) Do nothing can make you happy or joyful?",
                "10) Is your sex drive much higher than normal?",
                "11) Have you felt slower than normal , in your body or your mind , for a noticeable period of time?",
                "12) Are you a lot more confident or self-assured than normal?",
                "13) Do you feel like you couldn't sleep very much and feel like you didn't really need to?"
            ],
            "ALCOHOL DRUG ADDICTION TEST" : [
                "1) Have been drunk or taken drugs in the last week?",
                "2) Have you ever been stopped being friends with someone because of your drinking or drug use?",
                "3) Do you drink or use drugs in the morning?",
                "4) Have you ever been hospitalized due to drinking or drug taking?",
                "5) Have been drunk or taken drugs soon after waking in order to face the rest of the day?",
                "6) Do people close to you have comment negatively on your drinking or drug-taking?",
                "7) Does drinking or drugs negatively affect your ability to do your job?",
                "8) Do you ever feel ashamed about the amount of drink or drugs you use?",
                "9) Do your family member or friend has challenged you about drinking or using drugs?",
                "10) By drinking or drug use has cost you a job?",
                "11) Did you ever felt like you ought to seriously reduce your drinking or drug use?",
                "12) Did you ever felt like you need to quit drinking or drug use entirely?",
                "13) Have you lied about drinking or drug use?"
            ],
            "SOCIAL ANXIETY" : [
                "1) While making calls in public or where other people can hear you, have you picked up the call?",
                "2) Do you face anxiety while speaking in person with someone new?",
                "3) Do you feel anxious in situations where someone might try to sell you something?",
                "4) Do you face anxiety expressing a difference of opinion with someone you just met?",
                "5) Do you fear while speaking to someone you don't know on the phone?",
                "6) Do you feel anxiety taking unwanted purchases back to store?",
                "7) Do you feel anxious speaking to a teacher,manager, or someone in authority?",
                "8) Do you feel anxious being the focus of attention,or the person everyone is listening to?",
                "9) Do you feel fear using a public restroom where others might see you?",
                "10) Do you feel anxious while speaking in public?",
                "11) Can you keep eye contact with someone you just met?",
                "12) Do you feel awkward while meeting someone new for the first time?",
                "13) Did you ever feel anxious when Tested or assessed, particularly when you know people will likely know or be able to find out the result?"
            ],
            "SEPARATION ANXIETY" : [
                "1) Does separation has made you feel jittery or apprehensive?",
                "2) Have you tried to do and think things that will take your mind off being separated?",
                "3) Have you ever felt situations,events or activities early in order to get home?",
                "4) To deal with separation, you have used alcohol or otherwise self-medicated, or relied on superstitious behaviours?",
                "5) Does separation has made you feel horror,dread or great unease?",
                "6) Have you avoided places and situations where being separated is a possibility?",
                "7) Have you spent time and energy, on planning for being separated?",
                "8) Does separation has caused me physical reactions, for example difficulty, breathing, feeding,faint,dizzy ,or shaky?",
                "9) Does separation from people close to you has made you worry what negative things( for example , accidents or injuries might happen to them or to  me?",
                "10) Does separation has made you physically tense?",
                "11) Does separation has interrupted your sleep patterns?",
                "12) Does separation has made you struggle to remain calm?",
                "13)Does separation has made you feel unwanted by people?"
            ]
        }

        self.responses = {disorder: [tk.BooleanVar() for _ in questions] for disorder, questions in self.questions.items()}
        self.create_interface()

    def create_interface(self):
        ttk.Label(self.root, text="Select the disorder to assess:").pack()

        disorder_frame = ttk.Frame(self.root)
        disorder_frame.pack()

        disorders = ["None", "DEPRESSION", "ANXIETY", "PERSONALITY DISORDER", "EATING DISORDER",  "INTERNET ADDICTION DISORDER","SEX ADDICTION","FEMALE AGRESSION","SLEEP DISORDER", "VIDEO GAME ADDICTION","TOXIC WORKPLACE" , "MALE AGRESSION", "SCHIZOPHRENIA" ,"EMPATHY DEFICIT DISORDER TEST", "REPETITIVE THOUGHTS AND BEHAVIORS","PSYCHOSIS", "BIPOLAR DISORDER", "ALCOHOL DRUG ADDICTION TEST", "SOCIAL ANXIETY","SEPARATION ANXIETY"]
        for disorder in disorders:
            ttk.Radiobutton(
                disorder_frame,
                text=disorder,
                variable=self.disorder_var,
                value=disorder,
                command=self.show_questions
            ).pack(side=tk.TOP)

        self.question_frame = ttk.Frame(self.root)
        self.question_frame.pack()

        ttk.Button(self.root, text="Next", command=self.show_suggestion).pack()

    def show_questions(self):
        disorder = self.disorder_var.get()

        for widget in self.question_frame.winfo_children():
            widget.destroy()

        if disorder == "None":
            return

        questions = self.questions[disorder]
        for i, question in enumerate(questions):
            ttk.Checkbutton(
                self.question_frame,
                text=question,
                variable=self.responses[disorder][i]
            ).pack(anchor=tk.W)

    def show_suggestion(self):
        disorder = self.disorder_var.get()

        if disorder == "None":
            messagebox.showinfo("Suggestion", "Please select a disorder to assess.")
            return

        positive_responses = sum([response.get() for response in self.responses[disorder]])

        if disorder == "DEPRESSION":
            if positive_responses >= 7:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. You may be experiencing symptoms of depression, and early intervention can be beneficial."
            elif positive_responses >= 3:
                suggestion = "Based on your responses, their are some self-help books that will help you against depression:1.Change your Brain,Change your Life.,2.Full Catastrophe living."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of depression at this time. However, if you continue to feel down or experience changes in your mood, consider seeking support or counseling."
        elif disorder == "ANXIETY":
            if positive_responses >= 4:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. You may be experiencing symptoms of anxiety, and early intervention can be beneficial."
            elif positive_responses >= 1:
                suggestion = "Based on your responses their are some self-help books associated with anxiety:1.Dopamine Detox.,2.Anxiously Attached."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of anxiety at this time. However, if you continue to experience excessive worry or anxiety, consider seeking support or counseling."
        elif disorder == "PERSONALITY DISORDER":
            if positive_responses >= 4:
                suggestion = "Your responses suggest that you may have symptoms indicative of a personality disorder. It is important to seek evaluation and support from a mental health professional or therapist who specializes in personality disorders."
            elif positive_responses >= 2:
                suggestion = "Based on your responses that you have some concerns related to your personality traits and behavior their are some self-help books:1.The way She Feels.,2.I Hate You."  
            else:
                suggestion = "Based on your responses, it does not appear that you currently have symptoms of a personality disorder. However, if you have ongoing concerns, consider reaching out to a mental health provider for guidance."
        elif disorder == "EATING DISORDER":
            if positive_responses >= 5:
                suggestion = "Based on your responses, it is recommended that you seek help from a dietician professional. You may be experiencing symptoms of eating disorder and early intervention can be beneficial."
            elif positive_responses >= 3:
                suggestion = "Based on your responses I would suggest you some self-help books associated with Eating Disorder:1.Intuitive Eating.,2.Wisdom Of Your Body."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of eating disorder at this time. However, if you continue to feel low or experience changes in your mood, consider seeking support or counseling."
        elif disorder == "INTERNET ADDICTION DISORDER":
            if positive_responses >= 7:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. Early intervention can be beneficial."
            elif positive_responses >= 3:
                suggestion = "Based on your responses i would suggest you some self-help books associated with Internet addiction disorder:1.Technological Addictions.,2.The Art of Screen Time."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of internet addiction disorder at this time. However, if you continue to experience excessive worry, consider seeking support or counseling."
        elif disorder == "SEX ADDICTION" :
            if positive_responses >= 7:
                suggestion = "Your responses suggest that you may have symptoms indicative of a sex addiction disorder. It is important to seek evaluation and support from a mental health professional or therapist who specializes in sex addiction disorders."
            elif positive_responses >= 3:
                suggestion = "Based on your responses I would suggest you some self-help books related to your sex addiction:1.Understanding And treating Sex.,2.Don't Call It love."
            else:
                suggestion = "Based on your responses, it does not appear that you currently have symptoms of a sex addiction disorder. However, if you have ongoing concerns, consider reaching out to a mental health provider for guidance."
        elif disorder == "FEMALE AGRESSION":
            if positive_responses >= 7:
                suggestion = "Your responses suggest that you have some symptoms associated with female agression. It is important to seek evaluation and support from a mental health professional or therapist who specializes in female agression."
            elif positive_responses >= 3:
                suggestion =  "Based on your responses, I would recommended you some self-help books for female aggression:1.The Dance Of Anger,2.Mindfulness For Anger Management." 
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of female agression at this time. However, if you continue to feel that or experience , consider seeking support or counseling."
        elif disorder == "SLEEP DISORDER":
            if positive_responses >= 5:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. You may be experiencing symptoms of sleeping disorder and early intervention can be beneficial."
            elif positive_responses >= 3:
                suggestion = "Based on your responses I would suggest you some self-help books associated with sleeping disorder:1.Overcoming Insomnia And Sleep Problems.,2.The Sleep Solution."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of sleeping disorder at this time. However, if you continue to experience excessive worry , consider seeking support or counseling."
        elif disorder == "VIDEO GAME ADDICTION":
            if positive_responses >= 6:
                suggestion = "Your responses suggest that you may have symptoms indicative of a video game addiction disorder. It is important to seek evaluation and support from a mental health professional or therapist who specializes in video game addiction."
            elif positive_responses >= 2:
                suggestion = "Based on your responses I would suggest you some self-help books associated with video games addiction:1.The Power Of Habit.,2.The Slight Edge."
            else:
                suggestion = "Based on your responses, it does not appear that you currently have symptoms of a video game addiction disorder. However, if you have ongoing concerns, consider reaching out to a mental health provider for guidance."
        elif disorder == "TOXIC WORKPLACE":
            if positive_responses >= 7:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. You may be experiencing symptoms of toxic workplace, and early intervention can be beneficial."
            elif positive_responses >= 3:
                suggestion = "Based on your responses I would suggest you some self-help books associated with Toxic workplace:1.Rising Above a Toxic Workplace.,2.The No Asshole Rule."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of toxic workplace at this time. However, if you continue to feel down or experience changes in your mood, consider seeking support or counseling."
        elif disorder == "MALE AGRESSION":
            if positive_responses >= 7:
                suggestion = "Your responses suggest that you may have symptoms of male agression disorder. It is important to seek evaluation and support from a mental health professional or therapist who specializes male agression disorder."
            elif positive_responses >= 3:
                suggestion = "Based on your responses, I would  recommended  you some self-help books associated with Male aggression:1.Anger Management Workbook For Men.,2.Beyond Anger."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of Male agression at this time. However, if you continue to experience excessive worry , consider seeking support or counseling."
        elif disorder == "SCHIZOPHRENIA" :
            if positive_responses >= 8:
                suggestion = "Your responses suggest that you may have symptoms indicative of a schizophrenia disorder. It is important to seek evaluation and support from a mental health professional or therapist who specializes in schizophrenia disorders."
            elif positive_responses >= 4:
                suggestion = "Based your responses I would suggest you some self-help books related to Schizophrenia:1.The Beginner's Guide To Sanity,2.Instructions For Dealing with schizophrenia."
            else:
                suggestion = "Based on your responses, it does not appear that you currently have symptoms of a schizophrenia disorder. However, if you have ongoing concerns, consider reaching out to a mental health provider for guidance."
        elif disorder == "EMPATHY DEFICIT DISORDER TEST":
            if positive_responses >= 7:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. You may be experiencing symptoms of empathy deficit disorder, and early intervention can be beneficial."
            elif positive_responses >= 3:
                suggestion = "Based on your responses I would suggest you  some self-help books  associated with Empathy deficit disorder:1.The Art of Empathy.,2.Understanding And Loving a person With Attention Deficit Disorder."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of empathy deficit disorder at this time. However, if you continue to feel , consider seeking support or counseling."
        elif disorder == "REPETITIVE THOUGHTS AND BEHAVIORS":
            if positive_responses >= 4:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. You may be experiencing symptoms of repetitive thought and behaviors, early intervention can be beneficial."
            elif positive_responses >= 1:
                suggestion = "Based on your responses I would suggest you some self-help books associated with Repetitive thoughts and behaviors:1.Stop obsessing!,2.The Mindfulness Workbook For OCD."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of repetitive thoughts and behaviors at this time. However, if you continue to experience it, consider seeking support or counseling."
        elif disorder == "PSYCHOSIS":
            if positive_responses >= 7:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. You may be experiencing symptoms of psychosis, and early intervention can be beneficial."
            elif positive_responses >= 3:
                suggestion = "Based on your responses I would suggest you some self-helps books associated with Psychosis:1.Psychosis Recovery Guide.,2.Psychotherapy For Psychosis."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of psychosis at this time. However, if you continue to experience it, consider seeking support or counseling."        
        elif disorder == "BIPOLAR DISORDER":
            if positive_responses >= 7:
                suggestion = "Your responses suggest that you may have symptoms indicative of a bipolar disorder. It is important to seek evaluation and support from a mental health professional or therapist who specializes in bipolar disorders."
            elif positive_responses >= 3:
                suggestion = "Based on your responses I would suggest you some self-helps books related to bipolar disorder:1.An Unquiet Mind.,2.The Bipolar Disorder Survival Guide."
            else:
                suggestion = "Based on your responses, it does not appear that you currently have symptoms of a bipolar disorder. However, if you have ongoing concerns, consider reaching out to a mental health provider for guidance."
        elif disorder == "ALCOHOL DRUG ADDICTION TEST":
            if positive_responses >= 7:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. You may be experiencing alcohol and drug addiction, and early intervention can be beneficial."
            elif positive_responses >= 3:
                suggestion = "Based on your responses I would suggest you some self-help books associated with Alcohol Drug addiction:1.Girl Walks Out Of a Bar.,2.Drinking."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant alcohol drug addiction at this time. However, if you continue to experience changes , consider seeking support or counseling."
        elif disorder == "SOCIAL ANXIETY":
            if positive_responses >= 7:
                suggestion = "Based on your responses, it is recommended that you seek help from a mental health professional. You may be experiencing symptoms of social anxiety, and early intervention can be beneficial."
            elif positive_responses >= 3:
                suggestion = "Based on your responses, their are some self-help books that will help you against depression:1.Overcoming Social Anxiety and Shyness.,2.Painfully Shy."
            else:
                suggestion = "Based on your responses, it does not appear that you have significant symptoms of social anxiety at this time. However, if you continue to feel down or experience changes in your mood, consider seeking support or counseling."        
        elif disorder == "SEPARATION ANXIETY":
            if positive_responses >= 7:
                suggestion = "Your responses suggest that you may have symptoms indicative of a separation anxiety. It is important to seek evaluation and support from a mental health professional or therapist who specializes in separation anxiety."
            elif positive_responses >= 3:
                suggestion = "Based on your responses I would suggest you some self-help books:1.Separation Anxiety.,2.What To Do When You Don't Want To be Apart."
            else:
                suggestion = "Based on your responses, it does not appear that you currently have symptoms of a separation anxiety. However, if you have ongoing concerns, consider reaching out to a mental health provider for guidance."
        
        messagebox.showinfo("Suggestion", suggestion)

if __name__ == "__main__":
    root = tk.Tk()
    app = DisorderAssessment(root)
    root.mainloop()
